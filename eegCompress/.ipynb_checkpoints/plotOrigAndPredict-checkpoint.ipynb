# %%
# %matplotlib widget

import mne
import matplotlib.pyplot as plt
import numpy as np

# %%
path = '/blue/gkalamangalam/jmark.ettinger/eegCompress/processedData/origAndPredictedCorrected.npz'
temp = np.load(path)
data = temp['arr_0']
predictedCorrected = temp['arr_1']
residual = data - predictedCorrected

# %%
channel = 2

plt.figure()
plt.plot(predictedCorrected[channel,:])
plt.plot(data[channel,:])
#plt.plot(residual[channel,:])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Export to EDF

# %%
goodChannels = ['Fp1','F3','C3','P3','O1','Fp2','F4','C4','P4','O2','F7','T7','P7','F8','T8','P8','Fz','Cz','Pz']
info = mne.create_info(sfreq=256, ch_names=goodChannels)

path = '/blue/gkalamangalam/jmark.ettinger/eegCompress/processedData/eeg1.edf'
raw = mne.io.RawArray(data, info)
mne.export.export_raw(path, raw, fmt='edf', overwrite=True)

path = '/blue/gkalamangalam/jmark.ettinger/eegCompress/processedData/eeg2.edf'
raw = mne.io.RawArray(predictedCorrected, info)
mne.export.export_raw(path, raw, fmt='edf', overwrite=True)
# Out:
# Creating RawArray with float64 data, n_channels=19, n_times=1100367
#     Range : 0 ... 1100366 =      0.000 ...  4298.305 secs
# Ready.
# Creating RawArray with float64 data, n_channels=19, n_times=1100367
#     Range : 0 ... 1100366 =      0.000 ...  4298.305 secs
# Ready.
# /scratch/local/793987/ipykernel_1702628/3604978086.py:6: RuntimeWarning: EDF format requires equal-length data blocks, so 0.69140625 seconds of zeros were appended to all channels when writing the final block.
#   mne.export.export_raw(path, raw, fmt='edf', overwrite=True)
# /scratch/local/793987/ipykernel_1702628/3604978086.py:10: RuntimeWarning: EDF format requires equal-length data blocks, so 0.69140625 seconds of zeros were appended to all channels when writing the final block.
#   mne.export.export_raw(path, raw, fmt='edf', overwrite=True)
